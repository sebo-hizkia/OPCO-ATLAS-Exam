# %% [markdown]
# # Journal de bord

# %% [markdown]
# Construire et déployer un modèle d’IA prédictif du passage d’un élève au dernier trimestre

# %% [markdown]
# ## 📅 Journal de bord – Jour 1 (08/01/2026)

# %% [markdown]
# ### 🔧 Étapes / Actions réalisées
# - Chargement des deux jeux de données (mathématiques et portugais)
# - Analyse du script R fourni pour l’identification des élèves communs
# - Choix d’une stratégie de concaténation avec ajout d’une variable source
# - Implémentation de la fusion dans le notebook principal

# %% [markdown]
# ### 📝 Observations / Difficultés
# Le fichier des étudiants en portugais comporte 649 lignes de données ; le fichier des étudiants en mathématique en comporte 395. D'après le fichier de commentaire, 382 élèves sont en communs entre les deux fichiers. La fusion proposée dans le script R conserve uniquement ces élèves communs, ce qui conduit à réduire le jeu de données à 382 observations, contre 1044 observations disponibles initialement après concaténation. Cette perte d’environ 63 % des données est particulièrement conséquente pour un problème de prédiction supervisée. Par ailleurs, cette fusion regroupe sur une même ligne les notes d’un élève en mathématiques et en portugais, entraînant une duplication des notes trimestrielles (G1, G2, G3) sous des colonnes distinctes. Cette représentation rend la définition de la variable cible ambiguë dans un contexte de prédiction. Une concaténation avec ajout d’une variable source comme demandé dans l'énoncé a donc été privilégiée afin de conserver une observation par élève et par matière.

# %% [markdown]
# ### ✅ Prochaines étapes
# - Définir les variables sensibles à exclure dans le cadre des scénarios éthiques
# - Préparer les jeux de données correspondant aux différents scénarios d’entraînement
# - Débuter l’analyse exploratoire des données

# %% [markdown]
# ## 📅 Journal de bord – Jour 2 (09/01/2026)

# %% [markdown]
# ### 🔧 Étapes / Actions réalisées
# - Identification des variables pouvant être considérées comme sensibles
# - Analyse des risques de biais socio-économiques associés à certaines
#   caractéristiques personnelles et familiales
# - Définition de plusieurs scénarios d’entraînement conformément au sujet
# - Implémentation de ces scénarios dans le notebook de travail

# %% [markdown]
# ### 📝 Observations / Difficultés
# L’analyse exploratoire montre que la note finale G3 est fortement corrélée aux notes des trimestres précédents, en particulier G2. Ce qui justifie de tester les performances des modèles incluant ou non ces variables.
# En revanche, les variables sociodémographiques présentent des corrélations plus faibles avec la réussite scolaire, tandis que certaines variables comportementales, comme le nombre d’échecs passés ou le temps d’étude, apportent une information complémentaire.
#
# Certaines variables comportementales, telles que la consommation d’alcool en semaine et le week-end, peuvent être considérées comme sensibles dans un contexte éducatif, bien qu’elles ne relèvent pas de données d’identification directe. Je les ai donc retirées des scénarios sans variables sensibles.
#
# Le jeu de données est propre, il n'y a aucune données manquantes.
#
# Les premiers résultats de modélisation confirment cette analyse exploratoire : les scénarios incluant les notes intermédiaires atteignent des F1-scores supérieurs à 0,9, tandis que leur suppression entraîne une baisse progressive mais attendue des performances, notamment dans les scénarios les plus épurés.

# %% [markdown]
# ### ✅ Prochaines étapes
# - Comparer les performances des modèles sur les différents scénarios
# - Identifier le meilleur compromis entre performance, robustesse et considérations éthiques
# - Sélectionner un modèle final en vue de sa mise en production dans une API de prédiction

# %% [markdown]
# ## 📅 Journal de bord – Jour 3 (10/01/2026)

# %% [markdown]
# ### 🔧 Étapes / Actions réalisées
# - Comparaison des performances suivant les scénarios et les modèles
# - Identification du modèle avec le meilleur compromis entre performance, robustesse et considérations éthiques
# - Choix du modèle pour la phase industrialisation

# %% [markdown]
# ### 📝 Observations / Difficultés
# L'analyse par scénario montre que l'utilisation des variables sensibles n'a aucune incidence sur les performance des modèles, voire même une incidence légèrement négative. Ce qui renforce mon choix de ne pas suivre ce scénario.
# Cette analyse montre également que, logiquement sans la note du deuxième et/ou du troisième trimestre les performances chutes. Cependant, les prédictions restent assez robuste même sans la note du deuxième trimestre.
#
# Le modèle de régression logistique globalement le plus performant. Bien que les performances des différents modèles testés sont assez proche. Etant donné qu'il est en plus le modèle le plus simple et le plus explicable, cela en fait le meilleur choix.
#
# Je décide d'enregistrer pour la phase industrialisation les deux modèles de régression logistique sans variables sensibles suivants :
# - *avec* la note du deuxième trimestre
# - *sans* la note du deuxième trimestre

# %% [markdown]
# ### ✅ Prochaines étapes
# - Entâmer la phase industrialisation

# %% [markdown]
# ### 📅 Journal de bord – Jour 4 (13/01/2026)

# %% [markdown]
# ### 🔧 Étapes / Actions réalisées
# - Démarrage de la phase industrialisation en partant d'un template existant répondant à la structure du projet demandé
# - Implémentation du backend : inférence + routes
# - Implémentation du frontend : UI à destination des utilisateurs finaux

# %% [markdown]
# ### 📝 Observations / Difficultés
# Je suis parti d'un template de programme que nous avons créé lors de la formation. Il met à disposition la strucure suivante :
# ````
# frontend/  → interface utilisateur (Streamlit)
# backend/   → API FastAPI + logique métier
# docker-compose.yml → orchestration
# .github/   → CI/CD
# ````
# qui correspond à la demande du sujet.
#
# J'ai décidé de retenir deux modèles de régression logistique, l'un avec la note du deuxième trimestre et l'autre sans. En effet la prédiction avec seulement la note du premier trimestre est supérieure à 90%. Il serait dommage de ne pas l'exploiter. L'idée est de pouvoir donner une tendance une fois la note du premier trimestre connue pour lister les élèves à surveiller.

# %% [markdown]
# ### ✅ Prochaines étapes
# - Mise en place ré-entraînement monitoré
# - Mise en place mécanismes CI/CD

# %% [markdown]
# ### 📅 Journal de bord – Jour 5 (14/01/2026)

# %% [markdown]
# ### 🔧 Étapes / Actions réalisées
# - Mise en place middleware pour tracer les requêtes HTTP
# - Configuration GitHub Action

# %% [markdown]
# ### 📝 Observations / Difficultés
# Les logs sont gérés par loguru et enregistrés dans un fichier à l'intérieur du Docker. Ils sont également consultable en tant réel.
# A chaque push sur GitHub, la construction et le déploiement de l'image Docker se fait automtiquement sur un Docker Hub.

# %% [markdown]
# ### ✅ Prochaines étapes
# - Route de réentrainement avec monitoring
# - Monitoring de l'API

# %% [markdown]
# ### 📅 Journal de bord – Jour 6 (16/01/2026)

# %% [markdown]
# ### 🔧 Étapes / Actions réalisées
# - Implémentation d'un endpoint de réentrainement
# - Mise en place de MLFlow pour le monitoring des entrainements
# - Réalisation des slides pour la présentation

# %% [markdown]
# ### 📝 Observations / Difficultés
#
# La mise en place du ré-entrainement a soulevé plusieurs points techniques liés au passage à l’industrialisation.
# Tout d’abord, l’utilisation de la validation croisée lors du ré-entrainement nécessite un volume minimal de données, ce qui a impliqué d’adapter les jeux de test utilisés dans les tests automatisés afin d’éviter des erreurs liées au nombre de folds.
#
# Par ailleurs, le traitement des variables catégorielles a mis en évidence l’importance de conserver le même préprocessing entre l’entraînement et l’inférence.
#
# L’intégration de MLflow a également nécessité une réflexion sur la séparation des responsabilités :
# - l’API déclenche le ré-entrainement,
# - le module de ré-entrainement gère la logique métier,
# - MLflow assure la traçabilité et la comparaison des expériences.

# %% [markdown]
# ### ✅ Prochaines étapes
# - Ajouter le monitoring API
